# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/Wikipedia:Fundraising_statistics"
data=pd.read_html(url)

data
# Out:
# [       Year Source        Revenue       Expenses    Asset rise   Total assets
#  0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
#  1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
#  2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
#  3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
#  4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#  5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
#  6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
#  7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
#  8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
#  9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
#  10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising=data[0]
fundraising
# Out:
#        Year Source        Revenue       Expenses    Asset rise   Total assets
# 0   2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1   2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2   2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3   2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4   2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
# 5   2016/17    PDF   $ 91,242,418   $ 69,136,758  $ 21,547,402  $ 113,330,197
# 6   2015/16    PDF   $ 81,862,724   $ 65,947,465  $ 13,962,497   $ 91,782,795
# 7   2014/15    PDF   $ 75,797,223   $ 52,596,782  $ 24,345,277   $ 77,820,298
# 8   2013/14    PDF   $ 52,465,287   $ 45,900,745   $ 8,285,897   $ 53,475,021
# 9   2012/13    PDF   $ 48,635,408   $ 35,704,796  $ 10,260,066   $ 45,189,124
# 10  2011/12    PDF   $ 38,479,665   $ 29,260,652  $ 10,736,914   $ 34,929,058
# ...

# %%
fundraising["Rev"]=fundraising["Revenue"].str[2:]#2 means 2 ota pachi ko
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#            Rev        Exp
# 0  154,686,521  145970915
# 1  162,886,686  111839819
# 2  129,234,327  112489397
# 3  120,067,266   91414010
# 4  104,505,783   81442265

# %%
fundraising["Rev"]=fundraising["Rev"].str.replace(",","")
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev        Exp
# 0  154686521  145970915
# 1  162886686  111839819
# 2  129234327  112489397
# 3  120067266   91414010
# 4  104505783   81442265

# %%
fundraising["Rev"]=pd.to_numeric(fundraising["Rev"])# by default we convert the .astype(float)
fundraising.dtypes
# Out:
# Year            object
# Source          object
# Revenue         object
# Expenses        object
# Asset rise      object
# Total assets    object
# Rev              int64
# dtype: object

# %%
fundraising.drop(columns="Revenue")
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#           Rev
# 0  54686521.0
# 1  62886686.0
# 2  29234327.0
# 3  20067266.0
# 4   4505783.0

# %%
fundraising["Exp"]=fundraising["Expenses"].str[2:]
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev          Exp
# 0  154686521  145,970,915
# 1  162886686  111,839,819
# 2  129234327  112,489,397
# 3  120067266   91,414,010
# 4  104505783   81,442,265

# %%
fundraising["Exp"]=fundraising["Exp"].str.replace(",","")
fundraising["Exp"]=pd.to_numeric(fundraising["Exp"])
fundraising.drop(columns="Expenses")
fundraising.head()
# Out:
#       Year Source        Revenue       Expenses    Asset rise   Total assets  \
# 0  2021/22    PDF  $ 154,686,521  $ 145,970,915   $ 8,173,996  $ 239,351,532
# 1  2020/21    PDF  $ 162,886,686  $ 111,839,819  $ 50,861,811  $ 231,177,536
# 2  2019/20    PDF  $ 129,234,327  $ 112,489,397  $ 14,674,300  $ 180,315,725
# 3  2018/19    PDF  $ 120,067,266   $ 91,414,010  $ 30,691,855  $ 165,641,425
# 4  2017/18    PDF  $ 104,505,783   $ 81,442,265  $ 21,619,373  $ 134,949,570
#
#          Rev        Exp
# 0  154686521  145970915
# 1  162886686  111839819
# 2  129234327  112489397
# 3  120067266   91414010
# 4  104505783   81442265

# %%
fundraising["Exp"]=fundraising["Exp"].str.replace(",","")
fundraising["Exp"]=pd.to_numeric(fundraising["Exp"])
fundraising.drop(columns="Expenses")
fundraising.head()
