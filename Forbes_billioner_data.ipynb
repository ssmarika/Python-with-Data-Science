# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/uSer/Downloads/forbes_2022_billionaires.csv")
df
# Out:
#       rank                personName   age  finalWorth  year  month  \
# 0        1                 Elon Musk  50.0    219000.0  2022      4
# 1        2                Jeff Bezos  58.0    171000.0  2022      4
# 2        3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3        4                Bill Gates  66.0    129000.0  2022      4
# 4        5            Warren Buffett  91.0    118000.0  2022      4
# ...    ...                       ...   ...         ...   ...    ...
# 2663  2578             Zhang Yuqiang  66.0      1000.0  2022      4
# 2664  2578                Zhou Ruxin  59.0      1000.0  2022      4
# 2665  2578         Wen Zhou & family  57.0      1000.0  2022      4
# 2666  2578      Zhou Yifeng & family  43.0      1000.0  2022      4
# 2667  2578   Zhuang Kuilong & family  59.0      1000.0  2022      4
#
#                    category                   source        country  \
# 0                Automotive            Tesla, SpaceX  United States
# ...

# %%
df.shape #gives dimension rows and columns
# Out:
# (2668, 22)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df=df.loc[:, ['rank', 'personName', 'age', 'finalWorth','category', 'country', 'gender']]
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0    219000.0             Automotive
# 1     2                Jeff Bezos  58.0    171000.0             Technology
# 2     3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0    129000.0             Technology
# 4     5            Warren Buffett  91.0    118000.0  Finance & Investments
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2         France      M
# 3  United States      M
# 4  United States      M

# %%
df=df.set_index("rank")
df
# Out:
#                     personName   age  finalWorth               category  \
# rank
# 1                    Elon Musk  50.0    219000.0             Automotive
# 2                   Jeff Bezos  58.0    171000.0             Technology
# 3     Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 4                   Bill Gates  66.0    129000.0             Technology
# 5               Warren Buffett  91.0    118000.0  Finance & Investments
# ...                        ...   ...         ...                    ...
# 2578             Zhang Yuqiang  66.0      1000.0          Manufacturing
# 2578                Zhou Ruxin  59.0      1000.0             Technology
# 2578         Wen Zhou & family  57.0      1000.0          Manufacturing
# 2578      Zhou Yifeng & family  43.0      1000.0                 Energy
# 2578   Zhuang Kuilong & family  59.0      1000.0          Manufacturing
#
#             country gender
# rank
# 1     United States      M
# 2     United States      M
# ...

# %%
df.dtypes
# Out:
# personName     object
# age           float64
# finalWorth    float64
# category       object
# country        object
# gender         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# personName     0
# age           86
# finalWorth     0
# category       0
# country       13
# gender        16
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
df.isnull().sum()
# Out:
# personName    0
# age           0
# finalWorth    0
# category      0
# country       0
# gender        0
# dtype: int64

# %%
df.dtypes
# Out:
# personName     object
# age           float64
# finalWorth    float64
# category       object
# country        object
# gender         object
# dtype: object

# %%
df.shape
# Out:
# (2568, 6)

# %%
df["gender"].value_counts()
# Out:
# M    2282
# F     286
# Name: gender, dtype: int64

# %%
df["gender"].value_counts(normalize=True)
# Out:
# M    0.888629
# F    0.111371
# Name: gender, dtype: float64

# %%
df[df['country']=="France"].gender.value_counts(normalize=True)
# Out:
# M    0.878788
# F    0.121212
# Name: gender, dtype: float64

# %%
df["country"].describe()
# Out:
# count              2568
# unique               73
# top       United States
# freq                742
# Name: country, dtype: object

# %%
df["country"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
df[df["country"]=="Canada"].gender.value_counts(normalize=True)
# Out:
# M    0.952381
# F    0.047619
# Name: gender, dtype: float64

# %%
df[df["country"]=="Canada"].describe()
# Out:
#              age    finalWorth
# count  42.000000     42.000000
# mean   70.690476   4095.238095
# std    14.066893   7430.883228
# min    41.000000   1100.000000
# 25%    61.250000   1650.000000
# 50%    71.000000   2500.000000
# 75%    79.750000   4000.000000
# max    96.000000  49200.000000

# %%
df_gender=df.groupby(["gender"])

# %%
df_gender["age"].mean()
# Out:
# gender
# F    62.937063
# M    64.409290
# Name: age, dtype: float64

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set(rc={"figure.dpi":300})

# %%
df_gender.size().plot(kind="bar")
# Out:
# <Axes: xlabel='gender'>

# %%
sns.barplot(y=df["personName"][:10], x=df["finalWorth"][:10])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
len(df['country'].unique())
# Out:
# 73

# %%
df_country=df.groupby(["country"])

# %%
df_country_number=pd.DataFrame(df_country.size().sort_values(ascending=False),
                              columns=["numbers"])
df_country_number
# Out:
#                 numbers
# country
# United States       742
# China               546
# India               154
# Germany              94
# United Kingdom       81
# ...                 ...
# Andorra               1
# Liechtenstein         1
# Nepal                 1
# Oman                  1
# Algeria               1
#
# [73 rows x 1 columns]

# %%
sns.barplot(y=df_country_number.index[:10], x=df_country_number["numbers"][:10])
# Out:
# <Axes: xlabel='numbers', ylabel='country'>

# %%
df_france=df[df["country"]=="France"]
df_france
# Out:
#                                  personName   age  finalWorth  \
# rank
# 3                  Bernard Arnault & family  73.0    158000.0
# 14    Francoise Bettencourt Meyers & family  68.0     74800.0
# 31                  Rodolphe Saadé & family  52.0     41400.0
# 32                François Pinault & family  85.0     40400.0
# 63                         Emmanuel Besnier  51.0     23500.0
# 230                             Xavier Niel  54.0      8900.0
# 254                        Laurent Dassault  68.0      8400.0
# 254                        Thierry Dassault  65.0      8400.0
# 254            Marie-Hélène Habert-Dassault  57.0      8400.0
# 267                     Jean-Michel Besnier  54.0      8200.0
# 267                 Marie Besnier Beauvalot  41.0      8200.0
# 316                Vincent Bolloré & family  70.0      7500.0
# 369                  Alain Merieux & family  84.0      6700.0
# 728             Marc Ladreit de Lacharriere  81.0      4000.0
# ...

# %%
df_france["personName"].count()
# Out:
# 33

# %%
sns.barplot(y=df_france["personName"][:10], x=df_france["finalWorth"][:10])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
df_canada=df[df["country"]=="Canada"]
df_canada
# Out:
#                            personName   age  finalWorth  \
# rank
# 26             David Thomson & family  64.0     49200.0
# 152                      Jim Pattison  93.0     12200.0
# 254                 Anthony von Mandl  72.0      8400.0
# 509                       Chip Wilson  65.0      5300.0
# 552                    Alain Bouchard  73.0      5000.0
# 552                        Tobi Lutke  41.0      5000.0
# 586   Emanuele (Lino) Saputo & family  85.0      4800.0
# 637                        Daryl Katz  60.0      4500.0
# 687                      Carlo Fidani  67.0      4200.0
# 709                      James Irving  94.0      4100.0
# 728                     Arthur Irving  92.0      4000.0
# 728                   Alex Shevchenko  42.0      4000.0
# 913               Jean Coutu & family  94.0      3300.0
# 913                      Bob Gaglardi  81.0      3300.0
# 913                    Barry Zekelman  55.0      3300.0
# 951                      Peter Gilgan  71.0      3200.0
# ...

# %%
sns.barplot(y=df_canada["personName"][:10], x=df_canada["finalWorth"][:10])
# Out:
# <Axes: xlabel='finalWorth', ylabel='personName'>

# %%
df["category"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion_Retail',
#        'Finance_Investments', 'Diversified', 'Media_Entertainment',
#        'Telecom', 'Food_Beverage', 'Logistics', 'RealEstate',
#        'Metals_Mining', 'Manufacturing', 'Gambling_Casinos', 'Healthcare',
#        'Service', 'Energy', 'Construction_Engineering', 'Sports'],
#       dtype=object)

# %%
df["category"]=df["category"].apply(lambda x: x.replace(" ","")).\
apply(lambda x: x.replace("&","_"))

# %%
df["category"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion_Retail',
#        'Finance_Investments', 'Diversified', 'Media_Entertainment',
#        'Telecom', 'Food_Beverage', 'Logistics', 'RealEstate',
#        'Metals_Mining', 'Manufacturing', 'Gambling_Casinos', 'Healthcare',
#        'Service', 'Energy', 'Construction_Engineering', 'Sports'],
#       dtype=object)

# %%
df_category=df.groupby("category").size()

# %%
df_category
# Out:
#                             0
# category
# Automotive                 66
# Construction_Engineering   45
# Diversified               174
# Energy                     93
# Fashion_Retail            238
# Finance_Investments       381
# Food_Beverage             193
# Gambling_Casinos           23
# Healthcare                209
# Logistics                  32
# Manufacturing             319
# Media_Entertainment        95
# Metals_Mining              65
# RealEstate                187
# Service                    52
# Sports                     27
# Technology                332
# Telecom                    37

# %%
df_category=df_category.rename(columns=(0:"numbers"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df_category=df_category.to_frame()
#
# File C:\anaconda\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'
